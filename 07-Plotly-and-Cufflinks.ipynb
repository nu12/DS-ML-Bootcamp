# %% [markdown]
# # Plotly and Cufflinks
# Interactive data visualization.
# GitHub page: https://github.com/santosjorge/cufflinks
# Plotly cheat sheet: https://images.plot.ly/plotly-documentation/images/python_cheat_sheet.pdf
#
# ## Chart types:
# * histogram
# * scatter
# * bar
# * boxplot
# * 3d surface
# * spread
# * bubble
# * scatter_matrix

# %%
import numpy as np
import pandas as pd

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf
import chart_studio.plotly as py

# %%
init_notebook_mode(connected=True) # connect to the javascript of the Notebook
cf.go_offline() # use cufflinks offline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
# Data 1
df = pd.DataFrame(np.random.randn(100,4), columns='A B C D'.split())
df
# Out:
#            A         B         C         D
# 0   0.114915  0.866169 -0.189350  0.681018
# 1   1.154883  0.092315  1.024901 -1.507057
# 2   0.530649  0.455684  2.542778 -1.491434
# 3   2.214716 -1.187610 -1.410582  0.414576
# 4   1.653617  0.136826 -2.018224 -1.828696
# ..       ...       ...       ...       ...
# 95 -1.139887  0.605217  1.028651  0.342879
# 96 -1.419888 -0.738032 -0.681563 -1.399462
# 97  0.818649 -0.900694 -0.944249 -0.554774
# 98 -1.013978 -1.073427 -0.935059 -0.752853
# 99 -0.484779 -2.053360  1.283868  0.734423
#
# [100 rows x 4 columns]

# %%
# Data 2
df2 = pd.DataFrame({'Category': 'A B C'.split(), 'Values': [10, 22, 32]})
df2
# Out:
#   Category  Values
# 0        A      10
# 1        B      22
# 2        C      32

# %%
df.iplot()
# Out:
# <div>                            <div id="1dc151a1-e68e-4218-ab8c-2e629b83ab54" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='scatter', x='A', y='B', mode='markers')
# Out:
# <div>                            <div id="86f097e9-8420-4f57-8f45-37d78a0c9ac0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='scatter', x='A', y='B', mode='markers', size=2)
# Out:
# <div>                            <div id="e9db04b0-09e9-47ca-816c-b10f7bc161a1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df2.iplot(kind='bar', x='Category', y='Values')
# Out:
# <div>                            <div id="6c8b0526-7cfb-49be-b809-407dc30b74d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.sum().iplot(kind='bar')
# Out:
# <div>                            <div id="1380f5da-262a-4c95-93ca-48659e09b38e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='box')
# Out:
# <div>                            <div id="e1a34a8b-652b-464d-b4bf-176a3844fbf7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# Data 3
df3 = pd.DataFrame({'x': [1,2,3,4,5], 'y': [10,20,30,20,10], 'z': [5,4,3,2,1]})
df3
# Out:
#    x   y  z
# 0  1  10  5
# 1  2  20  4
# 2  3  30  3
# 3  4  20  2
# 4  5  10  1

# %%
df3.iplot(kind='surface')
# Out:
# <div>                            <div id="f973072a-4641-44cc-9b2e-db27dda5a39b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df3.iplot(kind='surface', colorscale='rdylbu')
# Out:
# <div>                            <div id="256ec035-2a37-4996-8ad6-6bb33ac004da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df['A'].iplot(kind='hist', bins=40)
# Out:
# <div>                            <div id="9ee04b83-83f0-411c-9d60-2498a4267a31" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='hist', bins=40)
# Out:
# <div>                            <div id="da41c348-79d3-4832-bf24-6f6d42e4cf3e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df[['A', 'B']].iplot(kind='spread')
# Out:
# E:\Users\Alysson\anaconda3\lib\site-packages\cufflinks\plotlytools.py:849: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#
# E:\Users\Alysson\anaconda3\lib\site-packages\cufflinks\plotlytools.py:850: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
# <div>                            <div id="3dcf8995-c38b-4e03-bcb9-4f1ec29ed716" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='bubble', x='A', y='B', size='C')
# Out:
# <div>                            <div id="7f7f3301-4bb8-4cc7-b49e-46d2b99fe605" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="317ea8a9-4e14-4c58-a425-da9eef685d35" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
